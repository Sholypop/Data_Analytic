# %%
# import Library
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#importing data

diamond_data = np.genfromtxt('diamonds.csv', delimiter=',')
diamond_data
# Out:
# array([[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#        [ nan, 0.23,  nan, ..., 3.95, 3.98, 2.43],
#        [ nan, 0.21,  nan, ..., 3.89, 3.84, 2.31],
#        ...,
#        [ nan, 0.7 ,  nan, ..., 5.66, 5.68, 3.56],
#        [ nan, 0.86,  nan, ..., 6.15, 6.12, 3.74],
#        [ nan, 0.75,  nan, ..., 5.83, 5.87, 3.64]])

# %%
diamond_data = np.genfromtxt('diamonds.csv', delimiter=',', skip_header=1, dtype='<U34')
diamond_data
# Out:
# array([['"1"', '0.23', '"Ideal"', ..., '3.95', '3.98', '2.43'],
#        ['"2"', '0.21', '"Premium"', ..., '3.89', '3.84', '2.31'],
#        ['"3"', '0.23', '"Good"', ..., '4.05', '4.07', '2.31'],
#        ...,
#        ['"53938"', '0.7', '"Very Good"', ..., '5.66', '5.68', '3.56'],
#        ['"53939"', '0.86', '"Premium"', ..., '6.15', '6.12', '3.74'],
#        ['"53940"', '0.75', '"Ideal"', ..., '5.83', '5.87', '3.64']],
#       dtype='<U34')

# %%
#importing the header

header_diamond_data = np.genfromtxt('diamonds.csv', delimiter=',', skip_footer=diamond_data.shape[0], dtype='<U34')
header_diamond_data
# Out:
# array(['""', '"carat"', '"cut"', '"color"', '"clarity"', '"depth"',
#        '"table"', '"price"', '"x"', '"y"', '"z"'], dtype='<U34')

# %%
#Studying the data

diamond_data.shape
# Out:
# (53940, 11)

# %%
'' in diamond_data
# Out:
# False

# %%
' ' in diamond_data
# Out:
# False

# %%
#working 
#header strings
header_diamond_data
# Out:
# array(['""', '"carat"', '"cut"', '"color"', '"clarity"', '"depth"',
#        '"table"', '"price"', '"x"', '"y"', '"z"'], dtype='<U34')

# %%
header_diamond_data[0]
# Out:
# '""'

# %%
#assigning name to the first column
header_diamond_data[0] = "index"

# %%
header_diamond_data
# Out:
# array(['index', '"carat"', '"cut"', '"color"', '"clarity"', '"depth"',
#        '"table"', '"price"', '"x"', '"y"', '"z"'], dtype='<U34')

# %%
#proper naming of the columns
header_diamond_data[3]= "Color-grade"
header_diamond_data[8]= "length in mm"
header_diamond_data[9]= "width in mm"
header_diamond_data[10]= "depth in mm"

# %%
header_diamond_data
# Out:
# array(['index', '"carat"', '"cut"', 'Color-grade', '"clarity"', '"depth"',
#        '"table"', '"price"', 'length in mm', 'width in mm', 'depth in mm'],
#       dtype='<U34')

# %%
# re arranging the columns
index_chnage = [0,1,7,2,3,4,5,6,8,9,10]

# %%
header_diamond_data[index_chnage]
# Out:
# array(['index', '"carat"', '"price"', '"cut"', 'Color-grade', '"clarity"',
#        '"depth"', '"table"', 'length in mm', 'width in mm', 'depth in mm'],
#       dtype='<U34')

# %%
header_diamond_data = header_diamond_data[index_chnage]
header_diamond_data
# Out:
# array(['index', '"carat"', '"price"', '"cut"', 'Color-grade', '"clarity"',
#        '"depth"', '"table"', 'length in mm', 'width in mm', 'depth in mm'],
#       dtype='<U34')

# %%
diamond_data
# Out:
# array([['"1"', '0.23', '"Ideal"', ..., '3.95', '3.98', '2.43'],
#        ['"2"', '0.21', '"Premium"', ..., '3.89', '3.84', '2.31'],
#        ['"3"', '0.23', '"Good"', ..., '4.05', '4.07', '2.31'],
#        ...,
#        ['"53938"', '0.7', '"Very Good"', ..., '5.66', '5.68', '3.56'],
#        ['"53939"', '0.86', '"Premium"', ..., '6.15', '6.12', '3.74'],
#        ['"53940"', '0.75', '"Ideal"', ..., '5.83', '5.87', '3.64']],
#       dtype='<U34')

# %%
diamond_data[:,index_chnage]
# Out:
# array([['"1"', '0.23', '326', ..., '3.95', '3.98', '2.43'],
#        ['"2"', '0.21', '326', ..., '3.89', '3.84', '2.31'],
#        ['"3"', '0.23', '327', ..., '4.05', '4.07', '2.31'],
#        ...,
#        ['"53938"', '0.7', '2757', ..., '5.66', '5.68', '3.56'],
#        ['"53939"', '0.86', '2757', ..., '6.15', '6.12', '3.74'],
#        ['"53940"', '0.75', '2757', ..., '5.83', '5.87', '3.64']],
#       dtype='<U34')

# %%
diamond_data = diamond_data[:,index_chnage]

# %%
# stacking the complete data

# %%
diamond_data.shape
# Out:
# (53940, 11)

# %%
header_diamond_data.shape
# Out:
# (11,)

# %%
np.vstack((header_diamond_data,diamond_data))
# Out:
# array([['index', '"carat"', '"price"', ..., 'length in mm',
#         'width in mm', 'depth in mm'],
#        ['"1"', '0.23', '326', ..., '3.95', '3.98', '2.43'],
#        ['"2"', '0.21', '326', ..., '3.89', '3.84', '2.31'],
#        ...,
#        ['"53938"', '0.7', '2757', ..., '5.66', '5.68', '3.56'],
#        ['"53939"', '0.86', '2757', ..., '6.15', '6.12', '3.74'],
#        ['"53940"', '0.75', '2757', ..., '5.83', '5.87', '3.64']],
#       dtype='<U34')

# %%
diamond_data = np.vstack((header_diamond_data,diamond_data))

# %%
diamond_data
# Out:
# array([['index', '"carat"', '"price"', ..., 'length in mm',
#         'width in mm', 'depth in mm'],
#        ['"1"', '0.23', '326', ..., '3.95', '3.98', '2.43'],
#        ['"2"', '0.21', '326', ..., '3.89', '3.84', '2.31'],
#        ...,
#        ['"53938"', '0.7', '2757', ..., '5.66', '5.68', '3.56'],
#        ['"53939"', '0.86', '2757', ..., '6.15', '6.12', '3.74'],
#        ['"53940"', '0.75', '2757', ..., '5.83', '5.87', '3.64']],
#       dtype='<U34')

# %%
#saving the data into a csv file
np.savetxt('completed-diamond-data.csv', diamond_data, fmt= '%s', delimiter=',')

# %%
#loading the saved csv data into panda frame

DF = pd.read_csv('completed-diamond-data.csv', delimiter= ',')
DF
# Out:
#        index  carat  price        cut Color-grade clarity  depth  table  \
# 0          1   0.23    326      Ideal           E     SI2   61.5   55.0
# 1          2   0.21    326    Premium           E     SI1   59.8   61.0
# 2          3   0.23    327       Good           E     VS1   56.9   65.0
# 3          4   0.29    334    Premium           I     VS2   62.4   58.0
# 4          5   0.31    335       Good           J     SI2   63.3   58.0
# ...      ...    ...    ...        ...         ...     ...    ...    ...
# 53935  53936   0.72   2757      Ideal           D     SI1   60.8   57.0
# 53936  53937   0.72   2757       Good           D     SI1   63.1   55.0
# 53937  53938   0.70   2757  Very Good           D     SI1   62.8   60.0
# 53938  53939   0.86   2757    Premium           H     SI2   61.0   58.0
# 53939  53940   0.75   2757      Ideal           D     SI2   62.2   55.0
#
#        length in mm  width in mm  depth in mm
# 0              3.95         3.98         2.43
# ...

# %%
DF.shape
# Out:
# (53940, 11)

# %%
#dropping the index column
DF.drop(['index'], axis=1)
# Out:
#        carat  price        cut Color-grade clarity  depth  table  \
# 0       0.23    326      Ideal           E     SI2   61.5   55.0
# 1       0.21    326    Premium           E     SI1   59.8   61.0
# 2       0.23    327       Good           E     VS1   56.9   65.0
# 3       0.29    334    Premium           I     VS2   62.4   58.0
# 4       0.31    335       Good           J     SI2   63.3   58.0
# ...      ...    ...        ...         ...     ...    ...    ...
# 53935   0.72   2757      Ideal           D     SI1   60.8   57.0
# 53936   0.72   2757       Good           D     SI1   63.1   55.0
# 53937   0.70   2757  Very Good           D     SI1   62.8   60.0
# 53938   0.86   2757    Premium           H     SI2   61.0   58.0
# 53939   0.75   2757      Ideal           D     SI2   62.2   55.0
#
#        length in mm  width in mm  depth in mm
# 0              3.95         3.98         2.43
# 1              3.89         3.84         2.31
# ...

# %%
DF = DF.drop(['index'], axis=1)
DF
# Out:
#        carat  price        cut Color-grade clarity  depth  table  \
# 0       0.23    326      Ideal           E     SI2   61.5   55.0
# 1       0.21    326    Premium           E     SI1   59.8   61.0
# 2       0.23    327       Good           E     VS1   56.9   65.0
# 3       0.29    334    Premium           I     VS2   62.4   58.0
# 4       0.31    335       Good           J     SI2   63.3   58.0
# ...      ...    ...        ...         ...     ...    ...    ...
# 53935   0.72   2757      Ideal           D     SI1   60.8   57.0
# 53936   0.72   2757       Good           D     SI1   63.1   55.0
# 53937   0.70   2757  Very Good           D     SI1   62.8   60.0
# 53938   0.86   2757    Premium           H     SI2   61.0   58.0
# 53939   0.75   2757      Ideal           D     SI2   62.2   55.0
#
#        length in mm  width in mm  depth in mm
# 0              3.95         3.98         2.43
# 1              3.89         3.84         2.31
# ...

# %%
DF.describe()
# Out:
#               carat         price         depth         table  length in mm  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean       0.797940   3932.799722     61.749405     57.457184      5.731157
# std        0.474011   3989.439738      1.432621      2.234491      1.121761
# min        0.200000    326.000000     43.000000     43.000000      0.000000
# 25%        0.400000    950.000000     61.000000     56.000000      4.710000
# 50%        0.700000   2401.000000     61.800000     57.000000      5.700000
# 75%        1.040000   5324.250000     62.500000     59.000000      6.540000
# max        5.010000  18823.000000     79.000000     95.000000     10.740000
#
#         width in mm   depth in mm
# count  53940.000000  53940.000000
# mean       5.734526      3.538734
# std        1.142135      0.705699
# min        0.000000      0.000000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.040000
# ...

# %%
#x,y,z have a zero minimum value. this indicate the data is faulty has it required 3 dimension measurement as indicated
#in the datset. index with 0 dimension will be filltered out.

# %%
# Dropping row index with 0 dimension
DF = DF.drop(DF[DF['length in mm']==0].index)
DF = DF.drop(DF[DF['width in mm']==0].index)
DF = DF.drop(DF[DF['depth in mm']==0].index)

# %%
DF.shape
# Out:
# (53920, 10)

# %%
# VISUALIZING THE DATA 

import seaborn as sns

# %%
sns.pairplot(DF)

# %%
visual = sns.pairplot(DF,hue='cut',palette='inferno')

# %%
visual
